# %%
import pandas as pd

# %%
books=pd.read_json('solr/current_book_data_25_10.json')
book_profiles = pd.read_json('solr/book_profiles_17_10.json')
reviews_1=pd.read_json('solr/reviews_part_1.json')
reviews_2=pd.read_json('solr/reviews_part_2.json')
reviews_3=pd.read_json('solr/reviews_part_3.json')
reviews_4=pd.read_json('solr/reviews_part_4.json')
reviews_5=pd.read_json('solr/reviews_part_5.json')
reviews_6=pd.read_json('solr/reviews_part_6.json')
reviews_7=pd.read_json('solr/reviews_part_7.json')
reviews_8=pd.read_json('solr/reviews_part_8.json')
reviews_9=pd.read_json('solr/reviews_part_9.json')
reviews_10=pd.read_json('solr/reviews_part_10.json')
reviews_11=pd.read_json('solr/reviews_part_11.json')
reviews_12=pd.read_json('solr/reviews_part_12.json')
reviews_13=pd.read_json('solr/reviews_part_13.json')
reviews_14=pd.read_json('solr/reviews_part_14.json')
reviews_15=pd.read_json('solr/reviews_part_15.json')
reviews_16=pd.read_json('solr/reviews_part_16.json')
reviews_17=pd.read_json('solr/reviews_part_17.json')
reviews_18=pd.read_json('solr/reviews_part_18.json')

# %%
reviews = reviews_1 + reviews_2 + reviews_3 + reviews_4 + reviews_5 + reviews_6 + reviews_7 + reviews_8 + reviews_9 + reviews_10 + reviews_11 + reviews_12 + reviews_13 + reviews_14 + reviews_15 + reviews_16 + reviews_17 + reviews_18

# %%
book_profiles.columns
book_profiles.drop(['id','rating_count', 'link'], axis=1, inplace=True)

# %%
merge_1=books.merge(book_profiles,how='inner', on='isbn')

# %%
merge_1
# Out:
#           id                               author book_format  \
# 0          0               [Laurence M. Hauptman]   Hardcover
# 1          1  [Charlotte Fiell, Emmanuelle Dirix]   Paperback
# 2          2                      [Andy Anderson]   Paperback
# 3          3               [Carlotta R. Anderson]   Hardcover
# 4          4                    [Jeffrey Pfeffer]   Hardcover
# ...      ...                                  ...         ...
# 70993  70993                       [Philip Hoare]   Paperback
# 70994  70994                         [Sarah Lean]   Paperback
# 70995  70995                     [C. John Miller]   Paperback
# 70996  70996                      [Albert Marrin]   Hardcover
# 70997  70997                      [Marc E. Fitch]       Ebook
#
#                                              description  \
# 0      Reveals that several hundred thousand Indians ...
# 1      Fashion Sourcebook - 1920s is the first book i...
# ...

# %%
reviews=reviews_1.append(reviews_2,ignore_index=True).append(reviews_3,ignore_index=True).append(reviews_4,ignore_index=True).append(reviews_5,ignore_index=True).append(reviews_6,ignore_index=True).append(reviews_7,ignore_index=True).append(reviews_8,ignore_index=True).append(reviews_9,ignore_index=True).append(reviews_10,ignore_index=True).append(reviews_11,ignore_index=True).append(reviews_12,ignore_index=True).append(reviews_13,ignore_index=True).append(reviews_14,ignore_index=True).append(reviews_15,ignore_index=True).append(reviews_16,ignore_index=True).append(reviews_17,ignore_index=True).append(reviews_18,ignore_index=True)
# Out:
# C:\Users\melis\AppData\Local\Temp\ipykernel_11972\2612395586.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews=reviews_1.append(reviews_2,ignore_index=True).append(reviews_3,ignore_index=True).append(reviews_4,ignore_index=True).append(reviews_5,ignore_index=True).append(reviews_6,ignore_index=True).append(reviews_7,ignore_index=True).append(reviews_8,ignore_index=True).append(reviews_9,ignore_index=True).append(reviews_10,ignore_index=True).append(reviews_11,ignore_index=True).append(reviews_12,ignore_index=True).append(reviews_13,ignore_index=True).append(reviews_14,ignore_index=True).append(reviews_15,ignore_index=True).append(reviews_16,ignore_index=True).append(reviews_17,ignore_index=True).append(reviews_18,ignore_index=True)

# %%
reviews
# Out:
#               id                                                url  \
# 0              0  https://goodreads.com/book/show/1002979.Jesus_...
# 1              1  https://goodreads.com/book/show/1002979.Jesus_...
# 2              2  https://goodreads.com/book/show/1002979.Jesus_...
# 3              3  https://goodreads.com/book/show/1002408.The_Su...
# 4              4  https://goodreads.com/book/show/1002979.Jesus_...
# ...          ...                                                ...
# 1264717  1264728  https://goodreads.com/book/show/17318645-the-w...
# 1264718  1264729  https://goodreads.com/book/show/17318645-the-w...
# 1264719  1264730  https://goodreads.com/book/show/17318645-the-w...
# 1264720  1264731  https://goodreads.com/book/show/17318645-the-w...
# 1264721  1264732  https://goodreads.com/book/show/17318645-the-w...
#
#                                                     review
# 0        This book is very important and should be read...
# ...

# %%
reviews = reviews.rename(columns={"url":"link"})

# %%
merge_1
# Out:
#           id                               author book_format  \
# 0          0               [Laurence M. Hauptman]   Hardcover
# 1          1  [Charlotte Fiell, Emmanuelle Dirix]   Paperback
# 2          2                      [Andy Anderson]   Paperback
# 3          3               [Carlotta R. Anderson]   Hardcover
# 4          4                    [Jeffrey Pfeffer]   Hardcover
# ...      ...                                  ...         ...
# 70993  70993                       [Philip Hoare]   Paperback
# 70994  70994                         [Sarah Lean]   Paperback
# 70995  70995                     [C. John Miller]   Paperback
# 70996  70996                      [Albert Marrin]   Hardcover
# 70997  70997                      [Marc E. Fitch]       Ebook
#
#                                              description  \
# 0      Reveals that several hundred thousand Indians ...
# 1      Fashion Sourcebook - 1920s is the first book i...
# ...

# %%
len(reviews.link.unique())
# Out:
# 65091

# %%
def map_reviews(link):
    return reviews[reviews['link'] == link]['review'].values

# %%
reviews_list=list(map(map_reviews, reviews.link.unique()))

# %%
d={'link':[],'review':[]}

# %%
d['link']=reviews.link.unique()

# %%
d['review']=reviews_list

# %%
df= pd.DataFrame(d)

# %%
merge_2 = merge_1.merge(df,how='inner', on='link')

# %%
merge_2.to_json('solr/merge_2.json')

# %%
import numpy as np
groups=np.array_split(merge_2, 18)

g1=groups[0]
'''
g2=groups[1]
g3=groups[2]
g4=groups[3]
g5=groups[4]
g6=groups[5]
g7=groups[6]
g8=groups[7]
g9=groups[8]
g10=groups[9]
g11=groups[10]
g12=groups[11]
g13=groups[12]
g14=groups[13]
g15=groups[14]
g16=groups[15]
g17=groups[16]
g18=groups[17]
'''
g1 = g1.loc[:, ~g1.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g1.to_json('test.json', orient='records')
'''
g2 = g2.loc[:, ~g2.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g2.to_json('solr/everything_part_2.json', orient='records')

g3 = g3.loc[:, ~g3.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g3.to_json('solr/everything_part_3.json', orient='records')

g4 = g4.loc[:, ~g4.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g4.to_json('solr/everything_part_4.json', orient='records')

g5 = g5.loc[:, ~g5.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g5.to_json('solr/everything_part_5.json', orient='records')

g6 = g6.loc[:, ~g6.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g6.to_json('solr/everything_part_6.json', orient='records')

g7 = g7.loc[:, ~g7.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g7.to_json('solr/everything_part_7.json', orient='records')

g8 = g8.loc[:, ~g8.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g8.to_json('solr/everything_part_8.json', orient='records')

g9 = g9.loc[:, ~g9.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g9.to_json('solr/everything_part_9.json', orient='records')

g10 = g10.loc[:, ~g10.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g10.to_json('solr/everything_part_10.json', orient='records')

g11 = g11.loc[:, ~g11.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g11.to_json('solr/everything_part_11.json', orient='records')

g12 = g12.loc[:, ~g12.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g12.to_json('solr/everything_part_12.json', orient='records')

g13 = g13.loc[:, ~g13.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g13.to_json('solr/everything_part_13.json', orient='records')

g14 = g14.loc[:, ~g14.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g14.to_json('solr/everything_part_14.json', orient='records')

g15 = g15.loc[:, ~g15.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g15.to_json('solr/everything_part_15.json', orient='records')

g16 = g16.loc[:, ~g16.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g16.to_json('solr/everything_part_16.json', orient='records')

g17 = g17.loc[:, ~g17.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g17.to_json('solr/everything_part_17.json', orient='records')

g18 = g18.loc[:, ~g18.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
g18.to_json('solr/everything_part_18.json', orient='records')
'''
# Out:
# "\ng2 = g2.loc[:, ~g2.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng2.to_json('solr/everything_part_2.json', orient='records')\n\ng3 = g3.loc[:, ~g3.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng3.to_json('solr/everything_part_3.json', orient='records')\n\ng4 = g4.loc[:, ~g4.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng4.to_json('solr/everything_part_4.json', orient='records')\n\ng5 = g5.loc[:, ~g5.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng5.to_json('solr/everything_part_5.json', orient='records')\n\ng6 = g6.loc[:, ~g6.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng6.to_json('solr/everything_part_6.json', orient='records')\n\ng7 = g7.loc[:, ~g7.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng7.to_json('solr/everything_part_7.json', orient='records')\n\ng8 = g8.loc[:, ~g8.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas\ng8.to_json('solr/every
# ...

# %% [markdown]
# ## Qrels processing

# %%
merge_3 = pd.read_json('solr/merge_2.json')

# %%
list_indexes = []
with open(r'q1_rels.txt', 'w') as fp:
    for index in merge_3.index:
        if(  (('Mystery' in merge_3.loc[index,'genre']) or ('Thriller' in merge_3.loc[index,'genre'])) and ( ('rape' not in merge_3.loc[index,'sensitivity'])  or ('sexual assault' not in merge_3.loc[index,'sensitivity']) or ('sexual content' not in merge_3.loc[index,'sensitivity']) or ('sexual harassment' not in merge_3.loc[index,'sensitivity']) or ('sexual violence' not in merge_3.loc[index,'sensitivity']) or ('sexual abuse' not in merge_3.loc[index,'sensitivity']) or ('gore' not in merge_3.loc[index,'sensitivity'])) and ( ('surprise' in merge_3.loc[index,'buzzwords']) or ('surprised' in merge_3.loc[index,'buzzwords']) or ('surprising' in merge_3.loc[index,'buzzwords'] )) or ('surprise' in merge_3.loc[index,'mood'])):
            list_indexes.append(merge_3.loc[index,'id'])
            fp.write(str(merge_3.loc[index,'id']) + '\n')

# %% [markdown]
# genre%5E10%20mood%20sensitivity%5E20%20buzzwords
# genre^10 mood sensitivity^20 buzzwords--> relevance doesn't really matter here because we use ands

# %%
list_indexes = []
#with open(r'q2_rels.txt', 'w') as fp:
for index in merge_3.index:
        if('fast' in merge_3.loc[index,'pacing']):
            #fp.write(str(merge_3.loc[index,'id']) + '\n')
            list_indexes.append(merge_3.loc[index,'id'])

# %%
list_indexes2 = []
#with open(r'q2_rels.txt', 'w') as fp:
for index in merge_3.index:
        if( (('surprise'  in merge_3.loc[index,'buzzwords']) or ('surprised' in merge_3.loc[index,'buzzwords']) or ('surprising' in merge_3.loc[index,'buzzwords'])) and ('twist' in merge_3.loc[index,'buzzwords'])):
            #fp.write(str(merge_3.loc[index,'id']) + '\n')
            list_indexes2.append(merge_3.loc[index,'id'])

# %%
list_final = list_indexes + list_indexes2

# %%
from collections import OrderedDict
list_for_file = list(OrderedDict.fromkeys(list_final))

# %%
len(list_for_file)

with open(r'q2_rels.txt', 'w') as fp:
    for i in list_for_file:
        fp.write(str(i) + '\n')

# %% [markdown]
# qf=pacing%20buzzwords%5E5&wt=json' ---> pacing more important

# %%
list_indexes3 = []
#with open(r'q3_rels.txt', 'w') as fp:
for index in merge_3.index:
        if( ( ('captivated'  in merge_3.loc[index,'buzzwords']) or ('captivating'  in merge_3.loc[index,'buzzwords'])) and (('obsessed' in merge_3.loc[index,'buzzwords']) or ('obsessively' in merge_3.loc[index,'buzzwords']))):
           # fp.write(str(merge_3.loc[index,'id']) + '\n')
            list_indexes3.append(merge_3.loc[index,'id'])

# %%
list_final2 = list_indexes + list_indexes3

# %%
from collections import OrderedDict
list_for_file2 = list(OrderedDict.fromkeys(list_final2))

# %%
with open(r'q3_rels.txt', 'w') as fp:
    for i in list_for_file2:
        fp.write(str(i) + '\n')

# %% [markdown]
# 10168
# fast once again weighs more so we add the others after

# %% [markdown]
# qf=title%5E10%20description%5E5&bq=title:batman
# title^10 description^5
# So 1- search for titles with batman in the title and nightwing in the description
# 2- search for titles with nightwing
# 3- search for descriptions with both batman and nightwing

# %%
merge_3.loc[merge_3['id']==7019]['description']
# Out:
# 6430    Every Man Has A Breaking Point.,Bruce Wayne ha...
# Name: description, dtype: object

# %%
import re
list_indexes4 = []
#with open(r'q4_rels.txt', 'w') as fp:
for index in merge_3.index:
        if(re.match('^(?=.*[a-zA-Z])',str(merge_3.loc[index,'title']))): 
                if((('batman' or 'Batman') in merge_3.loc[index,'title']) and (('nightwing' or 'Nightwing') in merge_3.loc[index, 'description'])):
           # fp.write(str(merge_3.loc[index,'id']) + '\n')
                        list_indexes4.append(merge_3.loc[index,'id'])
# Out:
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# Superman/Batman, Vol. 11: Worship
# ...
