# %%
import pandas as pd
import spacy

df = pd.read_csv('data/books_with_blurbs.csv', encoding="ANSI")

df = df['Blurb']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Melissa Silva\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def map_adjectives(text):
      tags = nltk.pos_tag(text.split(' '))
      adjectives = [w for w, t in tags if t == 'JJ']
      print(adjectives)
      return adjectives

# %%
df['adjectives'] = df.apply(map_adjectives)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] #delete Unnamed columns pandas
df['adjectives'].to_csv('buzzwords.csv')
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

tags = nltk.pos_tag(df[0].split(' '))
adjectives = [w for w, t in tags if t == 'JJ']
print(adjectives)
# Out:
# ['first', 'outstanding', 'military', 'dramatic', 'new']
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Melissa Silva\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
